# %% [markdown]
# # Знакомство с языком Python (семинары)
# ## Урок 11. Jupyter Notebook и несколько слов об аналитике
# Провести анализ, найти закономерности и сделать вывод

# %% [markdown]
# Каждая строчка наборов данных содержит следующие поля:
# Survived — выжил данный пассажир или нет (0 для умерших, 1 для выживших);
# Pclass — класс пассажира (1 — высший, 2 — средний, 3 — низший);
# Name — имя;
# Sex — пол;
# Age — возраст;
# SibSp — количество братьев, сестер, сводных братьев, сводных сестер, супругов на борту титаника;
# Parch — количество родителей, детей (в том числе приемных) на борту титаника;
# Ticket — номер билета;
# Fare — плата за проезд;
# Cabin — каюта;
# Embarked — порт посадки (C — Шербур; Q — Квинстаун; S — Саутгемптон).
# (Датасет прикреплен как файл - train (2).csv)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('train (2).csv', index_col='PassengerId')

# %%
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
train.head(5)   # выводит 5 элементов сверху таблицы
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
train.tail(3)   # выводит 3 элемента снизу таблицы
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train.info()   # общая информация о столбцах, кол-ве пропущенных значений, типе данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
train.isnull().values.any()   # определяет ниличие/отсутствие пропущенных значений в таблице
# Out:
# True

# %%
train.isnull().sum()   # выводит кол-во пропущенных значений по столбцам
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
train.shape   # выводит размер таблицы
# Out:
# (891, 11)

# %%
# удаляем ненужные колонки: Name - не несет смысловой нагрузки для дальнейшей обработки данных, \
                      # Cabin - около 80% данных не определены
train_clean = train.drop(columns=['Name', 'Cabin'])

# %%
train_clean
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch            Ticket  \
# PassengerId
# 1                   0       3    male  22.0      1      0         A/5 21171
# 2                   1       1  female  38.0      1      0          PC 17599
# 3                   1       3  female  26.0      0      0  STON/O2. 3101282
# 4                   1       1  female  35.0      1      0            113803
# 5                   0       3    male  35.0      0      0            373450
# ...               ...     ...     ...   ...    ...    ...               ...
# 887                 0       2    male  27.0      0      0            211536
# 888                 1       1  female  19.0      0      0            112053
# 889                 0       3  female   NaN      1      2        W./C. 6607
# 890                 1       1    male  26.0      0      0            111369
# 891                 0       3    male  32.0      0      0            370376
#
#                 Fare Embarked
# ...

# %% [markdown]
# ### Заполнение пропусков данных

# %%
def inpute_data(df):
    df_copy = df.copy()   # копируем во избежание потери оригинала
    
    # пропущенные значения в колонке Embarked будут заменены самым распространенным по столбцу
    str_vars = list(df_copy.select_dtypes(include=['object']).columns.values)
    for col in str_vars:
        if (df_copy[col].isnull().values.any()):
            df_copy[col].fillna(df_copy[col].mode()[0], inplace=True)
    
    # пропущенные значения в колонке Age будут заменены медианным значением по столбцу
    num_vars = list(df_copy.select_dtypes(include=['int64', 'float64']).columns.values)
    for col in num_vars:
        if (df_copy[col].isnull().values.any()):
            df_copy[col].fillna(df_copy[col].median(), inplace=True)
    
    return df_copy

# %%
train_full = inpute_data(train_clean)

# %%
train_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 69.6+ KB

# %% [markdown]
# ### Замена гендера mail/femail на child для Age <= 18

# %%
def update_data(df):
    df_copy = df.copy()
    df_copy.loc[(df.Age <= 18), ('Sex')] = 'child'
    
    return df_copy

# %%
train_SexChild = update_data(train_full)

# %%
train_SexChild.query('Age <= 18')
# Out:
#              Survived  Pclass    Sex   Age  SibSp  Parch    Ticket     Fare  \
# PassengerId
# 8                   0       3  child   2.0      3      1    349909  21.0750
# 10                  1       2  child  14.0      1      0    237736  30.0708
# 11                  1       3  child   4.0      1      1   PP 9549  16.7000
# 15                  0       3  child  14.0      0      0    350406   7.8542
# 17                  0       3  child   2.0      4      1    382652  29.1250
# ...               ...     ...    ...   ...    ...    ...       ...      ...
# 853                 0       3  child   9.0      1      1      2678  15.2458
# 854                 1       1  child  16.0      0      1  PC 17592  39.4000
# 856                 1       3  child  18.0      0      1    392091   9.3500
# 870                 1       3  child   4.0      1      1    347742  11.1333
# 876                 1       3  child  15.0      0      0      2667   7.2250
#
#             Embarked
# PassengerId
# ...

# %% [markdown]
# ### Визуализация данных

# %%
train_sex = train_SexChild.groupby(['Survived', 'Sex'], as_index=False).agg({'Ticket': 'count'}).sort_values('Sex', ascending=False)\
                    .rename(columns={'Ticket': 'count'})

# %%
train_sex
# Out:
#    Survived     Sex  count
# 2         0    male    421
# 5         1    male     85
# 1         0  female     59
# 4         1  female    187
# 0         0   child     69
# 3         1   child     70

# %%
sns.barplot(data=train_sex, x='Sex', y='count', hue='Survived', color='green')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# !!! Кол-во выживших женщин значительно превышает кол-во выживших мужчин, выживаемость детей 50 на 50 !!!

# %%
sns.catplot('Pclass', data=train_SexChild, hue='Survived', kind='count')
# Out:
# /Users/kalishka82/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# !!! Шанс на выживание пассажиров увеличивается с повышением класса !!!

# %%
plt.figure(figsize=(20, 10))
sns.catplot(x='Sex', y='Survived', col='Pclass', data=train_SexChild, kind='bar')

# %% [markdown]
# !!! Шанс на выживание пассажиров зависит от кол-ва членов семьи на борту !!!

# %% [markdown]
# !!! Шанс на выживание пассажиров зависит от присутсвтия родителей/детей на борту !!!

# %%
train_SexChild['Family'] = train_SexChild['SibSp'] + train_SexChild['Parch']

# %%
train_SexChild
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch            Ticket  \
# PassengerId
# 1                   0       3    male  22.0      1      0         A/5 21171
# 2                   1       1  female  38.0      1      0          PC 17599
# 3                   1       3  female  26.0      0      0  STON/O2. 3101282
# 4                   1       1  female  35.0      1      0            113803
# 5                   0       3    male  35.0      0      0            373450
# ...               ...     ...     ...   ...    ...    ...               ...
# 887                 0       2    male  27.0      0      0            211536
# 888                 1       1  female  19.0      0      0            112053
# 889                 0       3  female  28.0      1      2        W./C. 6607
# 890                 1       1    male  26.0      0      0            111369
# 891                 0       3    male  32.0      0      0            370376
#
#                 Fare Embarked  Family
# ...

# %%
sns.catplot('Family', data=train_SexChild, hue='Survived', kind='count')

# %% [markdown]
# !!! Выживаемость пассажиров выше при кол-ве членов семьи от 1 до 3 !!!
